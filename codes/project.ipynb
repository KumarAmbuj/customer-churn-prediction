# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
allcustomerchurn=pd.read_csv("H:/Decision Minds/folder1/AllCustomerChurnIndicator.csv",encoding="ISO-8859-1")
allcustomerchurn
# Out:
#      AccountNumber                                        AccountName  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
accountmetrics=pd.read_csv("H:/Decision Minds/folder1/AccountMetrics.csv",encoding="ISO-8859-1")
accountmetrics
# Out:
#      AccountNumber                                           AcctName  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC/IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3552   ACCT0078498                               Fujitsu - PersoPoint
# 3553   ACCT0079312                                Westfield Labs Corp
# 3554   ACCT0079408                                           IBM IS&T
# 3555   ACCT0080144                       Fujitsu - Frontoffice Center
# 3556   ACCT0080598                         FX Innovation - Jean Coutu
#
#      CustomerAgeCategoryIndicator  AcctPaymentStatusIndicator  \
# 0                               4                           2
# ...

# %%
#merging allcustomercurn and accountmetrics
result1 = pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left')
result1
# Out:
#      AccountNumber                                        AccountName  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
engagementsurveymetrics=pd.read_csv("H:/Decision Minds/folder1/EngagementSurveyMetrics.csv",encoding="ISO-8859-1")
engagementsurveymetrics
# Out:
#     AccountNumber                                 AccountName  \
# 0     ACCT0000026                         Clark County Nevada
# 1     ACCT0000045                       Harley-Davidson, Inc.
# 2     ACCT0000058                         Latham & Watkins LP
# 3     ACCT0000083                       Qualcomm Incorporated
# 4     ACCT0000114                  Toyota Motor Sales USA Inc
# ..            ...                                         ...
# 769   ACCT0066666                                 Midwich Ltd
# 770   ACCT0068036                         Lockheed Martin EBS
# 771   ACCT0068692                  CMG Corporate Services Inc
# 772   ACCT0068946                               Victorinox AG
# 773   ACCT0072614  Relationship Management Consultants NV RMC
#
#      OverallEngagementSatisfactionIndicator_SUM
# 0                                             1
# 1                                             1
# 2                                             2
# ...

# %%
result2=pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left')
result2
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
itsaavgprice=pd.read_csv("H:/Decision Minds/folder1/ITSAAvgPrice.csv",encoding="ISO-8859-1")
itsaavgprice
# Out:
#      AccountNumber  FulfillerPriceCategoryIndicator  Unnamed: 2  Unnamed: 3
# 0      ACCT0000006                              1.0         NaN         NaN
# 1      ACCT0000011                              1.0         NaN         NaN
# 2      ACCT0000026                              2.0         NaN         NaN
# 3      ACCT0000029                              1.0         NaN         NaN
# 4      ACCT0000034                              1.0         NaN         NaN
# ...            ...                              ...         ...         ...
# 3406   ACCT0078498                              1.0         NaN         NaN
# 3407   ACCT0079312                              3.0         NaN         NaN
# 3408   ACCT0079408                              2.0         NaN         NaN
# 3409   ACCT0080144                              1.0         NaN         NaN
# 3410   ACCT0080598                              2.0         NaN         NaN
#
# [3411 rows x 4 columns]

# %%
result3=pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left')
result3
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
knowledgeeventmetrics=pd.read_csv("H:/Decision Minds/folder1/KnowledgeEventMetrics.csv",encoding="ISO-8859-1")
knowledgeeventmetrics
# Out:
#      AccountNumber  KnowledgeEventAttendeeCount
# 0      ACCT0015703                            1
# 1      ACCT0009147                            9
# 2      ACCT0003590                           11
# 3      ACCT0004990                            8
# 4      ACCT0003563                           19
# ...            ...                          ...
# 1146   ACCT0009389                            1
# 1147   ACCT0007202                            1
# 1148   ACCT0015850                            1
# 1149   ACCT0006200                            1
# 1150   ACCT0004461                            1
#
# [1151 rows x 2 columns]

# %%
result4=pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
)
result4
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
licensedadoptionmetrics=pd.read_csv("H:/Decision Minds/folder1/LicensedAdoptionMetrics.csv",encoding="ISO-8859-1")
licensedadoptionmetrics
# Out:
#      AccountNumber                                           AcctName  \
# 0      ACCT0000006                                           OUHSC/IT
# 1      ACCT0000011                               Allstate Corporation
# 2      ACCT0000026                                Clark County Nevada
# 3      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# 4      ACCT0000034                                    Edmunds.com Inc
# ...            ...                                                ...
# 3114   ACCT0075133                                   Moravian College
# 3115   ACCT0075902                                 TEKsystems - Regis
# 3116   ACCT0076973                                             BT ITS
# 3117   ACCT0076981                       Deloitte Global Services Ltd
# 3118   ACCT0077830                                            ODH Inc
#
#      TotalAdoptionPercent LicensedAdoptionPercent  AdoptionCategoryIndicator  \
# ...

# %%
result5=pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
),licensedadoptionmetrics,on='AccountNumber',how='left')
result5
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
npsmetrics=pd.read_csv("H:/Decision Minds/folder1/NPSMetrics.csv",encoding="ISO-8859-1")
npsmetrics
# Out:
#      AccountNumber                                        AccountName  \
# 0      ACCT0000011                               Allstate Corporation
# 1      ACCT0000045                              Harley-Davidson, Inc.
# 2      ACCT0000051  International Financial Data Services (Canada)...
# 3      ACCT0000060                              Life Time Fitness Inc
# 4      ACCT0000069                Nationwide Mutual Insurance Company
# ...            ...                                                ...
# 1173   ACCT0040687                                            Technae
# 1174   ACCT0040690                                 Burleigh Point Ltd
# 1175   ACCT0048683                                 Cognizant - NVIDIA
# 1176   ACCT0048820                                           Ikano SA
# 1177   ACCT0059075                                      Costco Travel
#
#      ResponseRatePercent  NPSSatisfactionIndicator_SUM
# 0                     40                             4
# ...

# %%
result6=pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
),licensedadoptionmetrics,on='AccountNumber',how='left'),npsmetrics,on='AccountNumber',how='left')
result6
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
supportsurveymetrics=pd.read_csv("H:/Decision Minds/folder1/SupportSurveyMetrics.csv",encoding="ISO-8859-1")
supportsurveymetrics
# Out:
#      AccountNumber                                        AccountName  \
# 0      ACCT0000006                                           OUHSC/IT
# 1      ACCT0000011                               Allstate Corporation
# 2      ACCT0000026                                Clark County Nevada
# 3      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# 4      ACCT0000034                                    Edmunds.com Inc
# ...            ...                                                ...
# 1916   ACCT0072192                                         SAIC - JCC
# 1917   ACCT0072614         Relationship Management Consultants NV RMC
# 1918   ACCT0073287                                        Dell USA LP
# 1919   ACCT0074455             Isetan Mitsukoshi System Solutions Ltd
# 1920   ACCT0074922                  Econocom-Osiatis France - Allianz
#
#       OverallSupportSurveySatisfactionIndicator_SUM
# 0                                                 6
# ...

# %%
result7=pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
),licensedadoptionmetrics,on='AccountNumber',how='left'),npsmetrics,on='AccountNumber',how='left'),supportsurveymetrics,on='AccountNumber',how='left')
result7
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
usageindicator=pd.read_csv("H:/Decision Minds/folder1/UsageIndicator.csv",encoding="ISO-8859-1")
usageindicator
# Out:
#      AccountNumber  UsageRiskIndicator_SUM
# 0      ACCT0000006                       1
# 1      ACCT0000011                       0
# 2      ACCT0000026                       0
# 3      ACCT0000029                       0
# 4      ACCT0000034                       0
# ...            ...                     ...
# 3199   ACCT0076590                       0
# 3200   ACCT0076744                       0
# 3201   ACCT0076973                       0
# 3202   ACCT0076981                       6
# 3203   ACCT0077830                       0
#
# [3204 rows x 2 columns]

# %%
result8=pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
),licensedadoptionmetrics,on='AccountNumber',how='left'),npsmetrics,on='AccountNumber',how='left'),supportsurveymetrics,on='AccountNumber',how='left')
,usageindicator,on='AccountNumber',how='left')
result8
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
communitymetrics=pd.read_csv("H:/Decision Minds/folder1/CommunityMetrics.csv")
com=communitymetrics[:2567]
com
# Out:
#      AccountNumber TotalActivityCount_SUM  Unnamed: 2
# 0      ACCT0000006                    848         NaN
# 1      ACCT0000011                    242         NaN
# 2      ACCT0000026                    547         NaN
# 3      ACCT0000029                    490         NaN
# 4      ACCT0000034                     10         NaN
# ...            ...                    ...         ...
# 2562   ACCT0077830                     77         NaN
# 2563   ACCT0078498                      1         NaN
# 2564   ACCT0079408                     29         NaN
# 2565   ACCT0080144                      1         NaN
# 2566           NaN                    NaN         NaN
#
# [2567 rows x 3 columns]

# %%
result9=pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(allcustomerchurn,
                  accountmetrics,
                 on='AccountNumber', 
                 how='left'),engagementsurveymetrics,on='AccountNumber',how='left'),itsaavgprice[['AccountNumber','FulfillerPriceCategoryIndicator']],on='AccountNumber',how='left'),knowledgeeventmetrics,on='AccountNumber',how='left'
),licensedadoptionmetrics,on='AccountNumber',how='left'),npsmetrics,on='AccountNumber',how='left'),supportsurveymetrics,on='AccountNumber',how='left')
,usageindicator,on='AccountNumber',how='left'),com[['AccountNumber','TotalActivityCount_SUM']],on='AccountNumber',how='left')
result9
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
result9
# Out:
#      AccountNumber                                      AccountName_x  \
# 0      ACCT0000005                                   WagerWorks, Inc.
# 1      ACCT0000006                                           OUHSC IT
# 2      ACCT0000011                               Allstate Corporation
# 3      ACCT0000026                                Clark County Nevada
# 4      ACCT0000029  AAA Northern California, Nevada & Utah Insuran...
# ...            ...                                                ...
# 3553   ACCT0078498                               Fujitsu - PersoPoint
# 3554   ACCT0079312                                Westfield Labs Corp
# 3555   ACCT0079408                                           IBM IS&T
# 3556   ACCT0080144                       Fujitsu - Frontoffice Center
# 3557   ACCT0080598                         FX Innovation - Jean Coutu
#
#       CompleteCustomerChurn  \
# 0                         1
# 1                         0
# 2                         0
# ...

# %%
finalmerge = pd.DataFrame(result9)
finalmerge.to_csv('H:/Decision Minds/folder1/finalmerge.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-22-16614faa9eba> in <module>
#       1 finalmerge = pd.DataFrame(result9)
# ----> 2 finalmerge.to_csv('H:/Decision Minds/folder1/finalmerge.csv')
#
# c:\users\kumar ambuj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# c:\users\kumar ambuj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
# ...

# %%
dataset=pd.read_csv("H:/Decision Minds/folder1/finalmerge.csv")
dataset
